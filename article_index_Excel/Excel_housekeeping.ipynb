# %% [markdown]
# # Do some housekeeping on Stan's Excel worksheet
#
# To do:
# 1. Ensure ALL category names are consistent (no extra spaces, typos)
# 2. Spellcheck on all article titles
# 3. Display all author names for sanity check

# %%
import os
from openai import OpenAI
from tqdm import tqdm
import pandas as pd
from dotenv import load_dotenv

load_dotenv() #load your custom environment variables from .env file in same directory

client = OpenAI(
    api_key=os.environ.get("OPENAI_API_KEY"),
)

# %% [markdown]
# ## Load data

# %%
# Load the Excel file
excel_file = 'GRIT_INDEX_2024_10_OCT_backthrough2015.xlsx'

df_index = pd.read_excel(excel_file, sheet_name='INDEX', header=0)
df_histogram = pd.read_excel(excel_file, sheet_name='Histogram', header=2)

# Trim down relevant columns
df_index = df_index[df_index.columns[0:6]]

# Remove rows where there is not an entry in every column
df_index = df_index.dropna(how='any')
df_histogram = df_histogram.dropna(how='any')


# Convert all numbers to integers, then strings, and replace NaN values with empty strings
df_index = df_index.fillna('').map(lambda x: int(x) if isinstance(x, float) else x).astype('str')
df_histogram = df_histogram.fillna('').map(lambda x: int(x) if isinstance(x, float) else x).astype('str')

# %%
df_index
# Out:
#                                                  Title      First Author  \
# 0                    SHHA Annual Meeting announcements              SHHA
# 1                                   Covenant Violation       Dick Wavrik
# 2       Bernalilloo County Ordinance Regarding Animals               E&S
# 3                                      Light Pollution       Dick Wavrik
# 4                                  SHHA HOA Complaince              SHHA
# ..                                                 ...               ...
# 806                       How'd That Get There? Part 2        Stan Davis
# 807  Progress Being Made: Speed Enforcement Camera ...  Claudia Mitchell
# 808           Message from the President, October 2024       Jim Stewart
# 809                           SHHA Bylaws Under Review  Elizabeth Edgren
# 810    Let's Protect Our Momma Bear and her three Cubs            Editor
#
#     ~Relevant Committee              TOPIC  Year Month
# 0                  SHHA    ANN MTG/REPORTS  2015     1
# 1                   CSC  COVENANTS GENERAL  2015     1
# 2                   E&S          DOGS/PETS  2015     1
# 3                   CSC     OUTDOOR LIGHTS  2015     1
# 4                  SHHA               SHHA  2015     1
# ..                  ...                ...   ...   ...
# 806                 C&P            GEOLOGY  2024    10
# 807                 E&S    SAFETY/SECURITY  2024    10
# 808                SHHA               SHHA  2024    10
# 809                SHHA               SHHA  2024    10
# 810                 E&S    WILDLIFE(BEARS)  2024    10
#
# [809 rows x 6 columns]

# %% [markdown]
# ## View mismatched topics
#
# Check incorrect spaces, punctuation, or just missing Main Topics entries.

# %%
# Topic mismatch

topic_list = list(df_histogram['Main Topics'])
print('These topics are in the index but not in the Main Topics list :')
[f for f in set(list(df_index['TOPIC'])) if f not in topic_list]
# Out:
# These topics are in the index but not in the Main Topics list:
# ['SOLAR ',
#  'FIRE (GOATS)',
#  'SHHA ',
#  'RVs/BOATS',
#  'ANN MTG / REPORTS',
#  'COVENANTS GENERAL',
#  'PROPERTY  MAINT',
#  'CS&M',
#  'C&P']

# %% [markdown]
# ## Spellcheck and capitalization correction on article names

# %%
list(df_index['Title'])
# Out:
# 0                      SHHA Annual Meeting announcements
# 1                                     Covenant Violation
# 2         Bernalilloo County Ordinance Regarding Animals
# 3                                        Light Pollution
# 4                                    SHHA HOA Complaince
#                              ...
# 806                         How'd That Get There? Part 2
# 807    Progress Being Made: Speed Enforcement Camera ...
# 808             Message from the President, October 2024
# 809                             SHHA Bylaws Under Review
# 810      Let's Protect Our Momma Bear and her three Cubs
# Name: Title, Length: 809, dtype: object

# %%
# Function to correct spelling and capitalization using OpenAI
def fix_spelling_batch(titles, client):
    titles_text = '\n'.join([f"{i+1}. {title}" for i, title in enumerate(titles)])

    response = client.chat.completions.create(
        model="gpt-4o-mini",  # Specify the GPT-4o-mini model
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": f"Correct the spelling and capitalization of the titles below. \
            Reply with just the list as it appears, without any additional text.\n\n{titles_text}"}
        ]
        )
    corrected_text = response.choices[0].message.content.strip()
    
    # Split the corrected text back into individual titles
    corrected_titles = corrected_text.split('\n')
    
    # Remove the numbering and strip extra spaces from the corrected titles
    corrected_titles = [title.split('. ', 1)[-1].strip() for title in corrected_titles]
    return corrected_titles

# %%
# Split the titles into batches
batch_size = 80
corrected_titles = []

for i in tqdm(range(0, len(df_index), batch_size)):
    # Get the batch of titles
    batch = df_index['Title'].iloc[i:i+batch_size].tolist()
    
    # Correct the batch of titles
    corrected_batch = fix_spelling_batch(batch,client)
    
    # Append the corrected titles to the main list
    corrected_titles.extend(corrected_batch)

# Add the corrected titles to the dataframe
df_index['Corrected_Title'] = corrected_titles
# Out:
# 100%|███████████████████████████████████████████| 11/11 [01:50<00:00, 10.01s/it]

# %%
# Display the corrected titles
df_index[['Title', 'Corrected_Title']]
# Out:
#                                                  Title  \
# 0                    SHHA Annual Meeting announcements
# 1                                   Covenant Violation
# 2       Bernalilloo County Ordinance Regarding Animals
# 3                                      Light Pollution
# 4                                  SHHA HOA Complaince
# ..                                                 ...
# 806                       How'd That Get There? Part 2
# 807  Progress Being Made: Speed Enforcement Camera ...
# 808           Message from the President, October 2024
# 809                           SHHA Bylaws Under Review
# 810    Let's Protect Our Momma Bear and her three Cubs
#
#                                        Corrected_Title
# 0                    SHHA Annual Meeting Announcements
# 1                                   Covenant Violation
# 2        Bernalillo County Ordinance Regarding Animals
# 3                                      Light Pollution
# 4                                  SHHA HOA Compliance
# ..                                                 ...
# 806                       How'd That Get There? Part 2
# 807  Progress Being Made: Speed Enforcement Camera ...
# 808           Message from the President, October 2024
# 809                           SHHA Bylaws Under Review
# 810    Let's Protect Our Momma Bear and Her Three Cubs
#
# [809 rows x 2 columns]

# %%
# View every row that was changed

i_num = 0
for i,row in df_index.iterrows():
    if row['Title'] != row['Corrected_Title']:
        print(row['Title']+' | '+row['Corrected_Title'])
        i_num+=1
print('\n\n There were '+str(i_num)+' titles changed in total. ')
# Out:
# SHHA Annual Meeting announcements | SHHA Annual Meeting Announcements
# Bernalilloo County Ordinance Regarding Animals | Bernalillo County Ordinance Regarding Animals
# SHHA HOA Complaince | SHHA HOA Compliance
# SHHA Annual Meeting announcements | SHHA Annual Meeting Announcements
# Weed and Fire Season is Approaching! | Weed and Fire Season Is Approaching!
# Birds of Special Interest and Concern are Found in Sandia Heights | Birds of Special Interest and Concern Are Found in Sandia Heights
# Parks and Safety   | Parks and Safety
# Bear Season is Here | Bear Season Is Here
# Street Right of Way Maintenance | Street Right-of-Way Maintenance
# Zoning Variance Request made for a Domino's restaurant | Zoning Variance Request Made for a Domino's Restaurant
# Surveys and Building Permints - a Refresher | Surveys and Building Permits - A Refresher
# Don’t Feed The Bears | Don’t Feed the Bears
# SHHA Homeowner Members can Log onto the SHHA Website | SHHA Homeowner Members Can Log Onto the SHHA Website
# Architectural Observations 2: Blinded By the Light | Architectural Observations 2: Blinded by the Light
# Procedures for Attendance of Guests at SHHA Board and Committee Mtgs. | Procedures for Attendance of Guests at SHHA Board and Committee Meetings
# Sandia Heights Artists Studio Tour   | Sandia Heights Artists Studio Tour
# Humingbirds | Hummingbirds
# Short-Term Rentals, eg. Airbnb | Short-Term Rentals, e.g., Airbnb
# Pinon Pine | Piñon Pine
# Bernalillo County Mowing of Our Steets | Bernalillo County Mowing of Our Streets
# Monthly Fun Fact: Albuquerque name  | Monthly Fun Fact: Albuquerque Name
# Join the Welcom Wagon! | Join the Welcome Wagon!
# SH Tips & Hacks: Monthl winter and spring checks | SH Tips & Hacks: Monthly Winter and Spring Checks
# SH Tips & Hacks: monthly checks | SH Tips & Hacks: Monthly Checks
# Monthly Fun Fact: Albuquerque parks | Monthly Fun Fact: Albuquerque Parks
# Raptor Nexting Project Update | Raptor Nesting Project Update
# Welcome to each New Neighbor - Every Month | Welcome to Each New Neighbor - Every Month
# Woof! Woof! Is that YOUR Dog Barking? | Woof! Woof! Is That YOUR Dog Barking?
# Wildfire Workshop - Some of my Take Aways | Wildfire Workshop - Some of My Takeaways
# SH Tips & Hacks: Summer chores | SH Tips & Hacks: Summer Chores
# Pay it Forward | Pay It Forward
# Latest on Elena Gallegos Devlopment | Latest on Elena Gallegos Development
# Crisis: Not Yet - but getting too close! | Crisis: Not Yet - But Getting Too Close!
# It's Hot Out - for You and Your Dog | It's Hot Out - For You and Your Dog
# Mafic-nicent! | Mafic-nificent!
# Forest Service is Taking Comments on Relacing a Power Line | Forest Service is Taking Comments on Replacing a Power Line
# In a "Bind" Choosing a Contractor?  | In a "Bind": Choosing a Contractor?
# What is a Tutor Doctor | What is a Tutor Doctor?
# Your Monthly Recommendaton | Your Monthly Recommendation
# Letter to the Editor: Bears, rodents | Letter to the Editor: Bears, Rodents
# Complaint procedure guidelines | Complaint Procedure Guidelines
# How can  I shut off my water supply? | How Can I Shut Off My Water Supply?
# 2024 Annual Meeting Reerpots of Committees | 2024 Annual Meeting Reports of Committees
# Respectful Reques to Dog Owners/Walkers | Respectful Request to Dog Owners/Walkers
# Tramway Trash Pickup Scheduled this Month | Tramway Trash Pickup Scheduled This Month
# Shredding Even Saturday, June 29th  | Shredding Event Saturday, June 29th
# Trash Collection Help for Those with Disabilites | Trash Collection Help for Those with Disabilities
# It's Beautiful Out There, But Be Safe: Walk on the LEFT Side of the Road | It's Beautiful Out There, But Be Safe: Walk on the Left Side of the Road
# Success In Shreds? - thanks to your dues! | Success in Shreds? - Thanks to Your Dues!
# E-Bikes and Micromobility Devices Allowed in Open Space to be Discussed… | E-Bikes and Micromobility Devices Allowed in Open Space to Be Discussed…
# Sandia Heights Artists Tour: September 7 & 8 Enthusiams and Hard Work | Sandia Heights Artists Tour: September 7 & 8 Enthusiasm and Hard Work
# Committees Are Caontinuing Their Call: "Help!" | Committees Are Continuing Their Call: "Help!"
# Hear Ye! Hear Ye! Entire GRIT Archive is Now Online | Hear Ye! Hear Ye! Entire GRIT Archive Is Now Online
# Let's Protect Our Momma Bear and her three Cubs | Let's Protect Our Momma Bear and Her Three Cubs
#
#
#  There were 179 titles changed in total.

# %%
# Save to CSV

df_index[['Title', 'Corrected_Title']].to_csv('title_corrections.csv')

# %%
df_index.columns
# Out:
# Index(['Title', 'First Author', '~Relevant Committee', 'TOPIC', 'Year',
#        'Month', 'Corrected_Title'],
#       dtype='object')

# %%
# Update the original xlsx with the corrected titles

df_excel = pd.read_excel(excel_file, sheet_name='INDEX')
df_excel['Titles'] = df_index['Corrected_Title']
df_excel.to_excel(excel_file, sheet_name='INDEX', index=False)

# %% [markdown]
# ## View unique author names
#
# For spelling check.

# %%
set(list(df_index['First Author']))
# Out:
# {'ACC',
#  'Alex Deckard',
#  'Angela Moreno',
#  'Ann B. List',
#  'Anne Manning',
#  'Anonymous',
#  'Arthur Romero',
#  'Ben Abruzzo',
#  'BernCo',
#  'Bob Bower',
#  'Bob Thomas',
#  "Burt O'Neil",
#  'C&P',
#  'CS&M',
#  'CSC',
#  'Cathleen McCaughey',
#  'Cheryl Iverson',
#  'Cheryl Wieker',
#  'Cindi F.',
#  'Cindy Mottle',
#  'City of Albuquerque',
#  'Claudia Mitchell',
#  'Colleen Langan-McRoberts',
#  'Dale Arendt',
#  'Dan Benton',
#  'Dan Caudillo',
#  'Dave Mottle',
#  'David Crossley',
#  'David Wilson',
#  'Desert Oasis',
#  'Diane Barney',
#  'Dick Wavrick',
#  'Dick Wavrik',
#  'E&S',
#  'Editor',
#  'Eileen Karas',
#  'Elaine D. Briseno',
#  'Elizabeth Edgren',
#  'Emily Rudin',
#  'Eric Haskins',
#  'Erika Roesler',
#  'Franklin S.',
#  'George Connor',
#  'George Richmond',
#  'Haruki Murakami',
#  'Hugh Prather',
#  'Jan Randall',
#  'Janice Strand',
#  'Jean Hefflin',
#  'Jean Heflin (1988)',
#  'Jean Heflin (1991)',
#  'Jean Heflin (1993)',
#  'Jean Helfin',
#  'Jim Stewart',
#  'Jo Ann Hamlin',
#  'Joe Boyce',
#  'Joe Pappe',
#  'Jonathan Sutin',
#  'Josephine Porter',
#  'Judy Chreist',
#  'Judy Durzo',
#  'Judy Liddell',
#  'Julie Rochman',
#  'Karen P.',
#  'Kate Fry',
#  'Kate Fry  ',
#  'Kate Fry & Diane Barney',
#  'Katheleen McCahaughy',
#  'Kathleen McCaughey',
#  'Katrina Sanchez',
#  'Keith Julian',
#  'Letter to the Editor',
#  'Linda Burch',
#  'Mara Malnekoff',
#  'Marion Simon',
#  'Mary Schmauss',
#  'Matt Pedigo',
#  'Merrilea Mayo',
#  'Mick Rich',
#  'Mike Carson',
#  'Nancy Haubrich',
#  'Odile de la Beaujardiere',
#  'Paula Baxter',
#  'Randy Tripp',
#  'Rich Thomson',
#  'Richard Bracket',
#  'Robert Hare',
#  'Robert Thomas',
#  'Robert Trucksa',
#  'Roger Hagengruber',
#  'Ruth Baird Pollard',
#  'Ruth Frazier',
#  'Ruth Haas',
#  'SHHA',
#  'Sandia Hts. Services',
#  'Sandia Mt. Bearwatch',
#  'Sandia Peak Utility Co.',
#  'Spencer McKee',
#  'Stan Davis',
#  'Stephen Baca',
#  'Stephen S. Baca',
#  'Susan B.',
#  'Susan McCasland',
#  'Susan Seligman',
#  'Suzanne Schneider',
#  'Todd Fielder',
#  'Travis D. Rich',
#  'Travis Rich',
#  'Vivian George',
#  'William Koup',
#  'Woody Farber'}

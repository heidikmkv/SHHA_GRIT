# %% [markdown]
# # Update GRIT articles on the website from Stan's spreadsheet
#
# Prerequisites:
#
# Download content_grit.json from website.
#
# Download content_grit_category from website.

# %%
import pandas as pd
import re
import json
import os
from datetime import datetime
from calendar import month_name

month_mapping = {
    '1': 'january',
    '2': 'february',
    '3': 'march',
    '4': 'april',
    '5': 'may',
    '6': 'june',
    '7': 'july',
    '8': 'august',
    '9': 'september',
    '10': 'october',
    '11': 'november',
    '12': 'december'
}

# %% [markdown]
# ## read the exported json

# %%
with open('content_grit.json', mode='r') as file:
    all_issues = json.load(file)

with open('content_grit_category.json') as file:
    categories = json.load(file)

# %%
categories_id_to_name = {category['id']:category['title'] for category in categories}
categories_name_to_id = {v:k for k,v in categories_id_to_name.items()}

# %%
categories_name_to_id
# Out:
# {'Architectural Control Committee': 2,
#  'ANN MTG / REPORTS': 3,
#  'ART': 5,
#  'BERNCO': 6,
#  'BERNCO(NOISE)': 7,
#  'BERNCO(ROADS)': 8,
#  'COMMUNITY': 9,
#  'COVENANTS GENERAL': 10,
#  'DOGS/PETS': 11,
#  'DRONES': 12,
#  'ELENA GALLEGOS': 13,
#  'ENVIRONMENT': 14,
#  'FIRE': 15,
#  'FIRE (GOATS)': 16,
#  'FLORA/PLANTS/TREES': 17,
#  'GEOLOGY': 18,
#  'GRIT': 19,
#  'HISTORY/ARCHAEOLOGY': 20,
#  'HUNTING': 21,
#  'INVASIVE PLANTS/TREES': 22,
#  'LANDSCAPING': 23,
#  'OUTDOOR LIGHTS': 24,
#  'PROPERTY MAINT': 25,
#  'RADON': 26,
#  'RENTALS': 27,
#  'RVs/BOATS': 28,
#  'SAFETY/SECURITY': 29,
#  'SEPTIC SYSTEMS / GRAY WATER': 30,
#  'SHHA': 31,
#  'SOLAR': 32,
#  'TRASH BINS': 33,
#  'TRASH GENERAL': 34,
#  'WILDLIFE(BATS)': 35,
#  'WILDLIFE(BEARS)': 36,
#  'WILDLIFE(BIRDS)': 37,
#  'WILDLIFE(COYOTES)': 38,
#  'WILDLIFE(DEER)': 39,
#  'WILDLIFE(GENERAL)': 40,
#  'WILDLIFE(INSECTS/SPIDERS)': 41,
#  'WILDLIFE(RODENTS)': 42,
#  'WILDLIFE(SNAKES/REPTILES)': 43,
#  'WILDLIFE(WILDCATS)': 44}

# %%
issue = all_issues[0]
issue
# Out:
# {'id': 352,
#  'title': 'October, 2024 GRIT',
#  'slug': 'october-2024-grit',
#  'is_enabled': 1,
#  'published_at': None,
#  'expired_at': None,
#  'content_group': None,
#  'grit_date': '2024-10-01 20:26:42',
#  'file': '/grit/2024/Oct 2024 Color GRIT.pdf',
#  'image': ['/grit/2024/oct_2024_thumbnail.png'],
#  'content': '<p>In the October 2024 issue of the GRIT, the SHHA President issued a call for new Board members, as well as a reminder that leaving food outside – whether in trash or containers – was a danger to bears, as they would likely have to be trapped and euthanized. The latter message was also mirrored in an article about Sandia Heights sightings of a mother bear and her three cubs. October’s monthly human-interest feature centered on resident Mary Cleo Fernandez. Author Claudia Mitchell chronicled Mary Cleo’s exceptional support for Casa Angelica, a home for individuals with profound developmental disabilities. In addition, there was a stirring memorial to Wade Jackson, by authors Katrina Sanchez and Viki Teahan. Wade was the selfless local attorney responsible for successfully challenging the City of Albuquerque for, and obtaining an injunction against, its planned construction of a large Education Center on the Elena Gallegos Open Space Preserve, which borders Sandia Heights. The October GRIT also featured Part II of the geology article by Stan Davis on why Sandia Heights has so many big rounded boulders on its trails and in its open spaces. Sprinkled throughout the issue are several short articles: a reminder to register to vote, a notice that SHHA Bylaws are being reviewed, a summary of the recent calls to Sandia Heights Security, the recently approved Architectural Control Committee applications, and the recently closed covenant support violations.</p>',
#  'articles': [{'title': 'Message from the President, October 2024',
#    'author': 'Jim Stewart',
#    'site_id': None,
#    'content_group': None,
#    'sort_order': 4182,
#    'created_at': '2024-10-11 17:43:56',
#    'updated_at': '2024-10-11 17:43:56',
#    'parent_id': None,
#    'category': [31]},
#   {'title': 'Spotlight on Casa Angelica Support from Sandia Heights Resident',
#    'author': 'Claudia Mitchell',
#    'site_id': None,
#    'content_group': None,
#    'sort_order': 4183,
#    'created_at': '2024-10-11 17:46:25',
#    'updated_at': '2024-10-11 17:46:25',
#    'parent_id': None,
#    'category': [9]},
#   {'title': 'Progress Being Made: Speed Enforcement Camera Proposed for Tramway',
#    'author': 'Claudia Mitchell',
#    'site_id': None,
#    'content_group': None,
#    'sort_order': 4184,
#    'created_at': '2024-10-11 17:47:41',
#    'updated_at': '2024-10-11 17:47:41',
#    'parent_id': None,
#    'category': [29]},
#   {'title': 'In Memory of Wade Jackson and His Legacy to Elena Gallegos',
#    'author': 'Katrina Sanchez',
#    'site_id': None,
#    'content_group': None,
#    'sort_order': 4185,
#    'created_at': '2024-10-11 17:48:24',
#    'updated_at': '2024-10-11 17:48:25',
#    'parent_id': None,
#    'category': [13]},
#   {'title': 'SHHA Bylaws Under Review',
#    'author': 'Elizabeth Edgren',
#    'site_id': None,
#    'content_group': None,
#    'sort_order': 4186,
#    'created_at': '2024-10-11 17:50:21',
#    'updated_at': '2024-10-11 17:50:21',
#    'parent_id': None,
#    'category': [31]},
#   {'title': 'Thanks from the Sandia Heights Artists',
#    'author': 'Claudia Mitchell',
#    'site_id': None,
#    'content_group': None,
#    'sort_order': 4187,
#    'created_at': '2024-10-11 17:51:10',
#    'updated_at': '2024-10-11 17:51:10',
#    'parent_id': None,
#    'category': [5]},
#   {'title': "How'd That Get There? Part 2",
#    'author': 'Stan Davis',
#    'site_id': None,
#    'content_group': None,
#    'sort_order': 4188,
#    'created_at': '2024-10-11 17:51:51',
#    'updated_at': '2024-10-11 17:51:51',
#    'parent_id': None,
#    'category': [18]},
#   {'title': '2025 Directory Cover Photo Contest Deadline, November 8',
#    'author': 'C&P',
#    'site_id': None,
#    'content_group': None,
#    'sort_order': 4189,
#    'created_at': '2024-10-11 17:52:48',
#    'updated_at': '2024-10-11 17:52:48',
#    'parent_id': None,
#    'category': [9]},
#   {'title': 'Hear Ye! Hear Ye! Entire GRIT Archive is Now Online',
#    'author': 'Susan McCasland',
#    'site_id': None,
#    'content_group': None,
#    'sort_order': 4190,
#    'created_at': '2024-10-11 17:53:47',
#    'updated_at': '2024-10-11 17:53:47',
#    'parent_id': None,
#    'category': [9]},
#   {'title': "Let's Protect Our Momma Bear and her three Cubs",
#    'author': 'Editor',
#    'site_id': None,
#    'content_group': None,
#    'sort_order': 4191,
#    'created_at': '2024-10-11 17:54:49',
#    'updated_at': '2024-10-11 17:54:50',
#    'parent_id': None,
#    'category': [36]}]}

# %%
# Import the new entries from Stan, saved as CSV

df = pd.read_csv('Articles_pre2017.csv')
df = df.astype('str')

df['slug'] = df.apply(lambda row: month_mapping[row['Month']] + '-' + str(row['Year']) + '-grit', axis=1)

# %%
issue
# Out:
# {'id': 352,
#  'title': 'October, 2024 GRIT',
#  'slug': 'october-2024-grit',
#  'is_enabled': 1,
#  'published_at': None,
#  'expired_at': None,
#  'content_group': None,
#  'grit_date': '2024-10-01 20:26:42',
#  'file': '/grit/2024/Oct 2024 Color GRIT.pdf',
#  'image': ['/grit/2024/oct_2024_thumbnail.png'],
#  'content': '<p>In the October 2024 issue of the GRIT, the SHHA President issued a call for new Board members, as well as a reminder that leaving food outside – whether in trash or containers – was a danger to bears, as they would likely have to be trapped and euthanized. The latter message was also mirrored in an article about Sandia Heights sightings of a mother bear and her three cubs. October’s monthly human-interest feature centered on resident Mary Cleo Fernandez. Author Claudia Mitchell chronicled Mary Cleo’s exceptional support for Casa Angelica, a home for individuals with profound developmental disabilities. In addition, there was a stirring memorial to Wade Jackson, by authors Katrina Sanchez and Viki Teahan. Wade was the selfless local attorney responsible for successfully challenging the City of Albuquerque for, and obtaining an injunction against, its planned construction of a large Education Center on the Elena Gallegos Open Space Preserve, which borders Sandia Heights. The October GRIT also featured Part II of the geology article by Stan Davis on why Sandia Heights has so many big rounded boulders on its trails and in its open spaces. Sprinkled throughout the issue are several short articles: a reminder to register to vote, a notice that SHHA Bylaws are being reviewed, a summary of the recent calls to Sandia Heights Security, the recently approved Architectural Control Committee applications, and the recently closed covenant support violations.</p>',
#  'articles': [{'title': 'Message from the President, October 2024',
#    'author': 'Jim Stewart',
#    'site_id': None,
#    'content_group': None,
#    'sort_order': 4182,
#    'created_at': '2024-10-11 17:43:56',
#    'updated_at': '2024-10-11 17:43:56',
#    'parent_id': None,
#    'category': [31]},
#   {'title': 'Spotlight on Casa Angelica Support from Sandia Heights Resident',
#    'author': 'Claudia Mitchell',
#    'site_id': None,
#    'content_group': None,
#    'sort_order': 4183,
#    'created_at': '2024-10-11 17:46:25',
#    'updated_at': '2024-10-11 17:46:25',
#    'parent_id': None,
#    'category': [9]},
#   {'title': 'Progress Being Made: Speed Enforcement Camera Proposed for Tramway',
#    'author': 'Claudia Mitchell',
#    'site_id': None,
#    'content_group': None,
#    'sort_order': 4184,
#    'created_at': '2024-10-11 17:47:41',
#    'updated_at': '2024-10-11 17:47:41',
#    'parent_id': None,
#    'category': [29]},
#   {'title': 'In Memory of Wade Jackson and His Legacy to Elena Gallegos',
#    'author': 'Katrina Sanchez',
#    'site_id': None,
#    'content_group': None,
#    'sort_order': 4185,
#    'created_at': '2024-10-11 17:48:24',
#    'updated_at': '2024-10-11 17:48:25',
#    'parent_id': None,
#    'category': [13]},
#   {'title': 'SHHA Bylaws Under Review',
#    'author': 'Elizabeth Edgren',
#    'site_id': None,
#    'content_group': None,
#    'sort_order': 4186,
#    'created_at': '2024-10-11 17:50:21',
#    'updated_at': '2024-10-11 17:50:21',
#    'parent_id': None,
#    'category': [31]},
#   {'title': 'Thanks from the Sandia Heights Artists',
#    'author': 'Claudia Mitchell',
#    'site_id': None,
#    'content_group': None,
#    'sort_order': 4187,
#    'created_at': '2024-10-11 17:51:10',
#    'updated_at': '2024-10-11 17:51:10',
#    'parent_id': None,
#    'category': [5]},
#   {'title': "How'd That Get There? Part 2",
#    'author': 'Stan Davis',
#    'site_id': None,
#    'content_group': None,
#    'sort_order': 4188,
#    'created_at': '2024-10-11 17:51:51',
#    'updated_at': '2024-10-11 17:51:51',
#    'parent_id': None,
#    'category': [18]},
#   {'title': '2025 Directory Cover Photo Contest Deadline, November 8',
#    'author': 'C&P',
#    'site_id': None,
#    'content_group': None,
#    'sort_order': 4189,
#    'created_at': '2024-10-11 17:52:48',
#    'updated_at': '2024-10-11 17:52:48',
#    'parent_id': None,
#    'category': [9]},
#   {'title': 'Hear Ye! Hear Ye! Entire GRIT Archive is Now Online',
#    'author': 'Susan McCasland',
#    'site_id': None,
#    'content_group': None,
#    'sort_order': 4190,
#    'created_at': '2024-10-11 17:53:47',
#    'updated_at': '2024-10-11 17:53:47',
#    'parent_id': None,
#    'category': [9]},
#   {'title': "Let's Protect Our Momma Bear and her three Cubs",
#    'author': 'Editor',
#    'site_id': None,
#    'content_group': None,
#    'sort_order': 4191,
#    'created_at': '2024-10-11 17:54:49',
#    'updated_at': '2024-10-11 17:54:50',
#    'parent_id': None,
#    'category': [36]}]}

# %%
# iterate through unique slugs and create a json with the new article data
issues_to_update = []

for slug in df['slug'].unique():
    issue = [issue for issue in all_issues if issue['slug']==slug][0]
    print('Updating: ' + issue['title'])
    df_issue = df[df['slug']==slug]
    new_article_list = []
    for i, row in df_issue.iterrows():
        article_dict = {}
        article_dict['title'] = row['Title']
        article_dict['author'] = row['First Author']
        article_dict['created_at'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        article_dict['category'] = [str(categories_name_to_id[row['TOPIC']])]
        new_article_list.append(article_dict)
    
    # Select fields to include in update JSON that's uploaded to website
    issue_update = {}
    issue_update['id'] = issue['id']
    issue_update['slug'] = slug
    issue_update['articles'] = new_article_list
    #issue['articles'] = new_article_list
    
    issues_to_update.append(issue_update)


# Save the dictionary as a JSON file
with open('updated_articles.json', 'w') as json_file:
    json.dump(issues_to_update, json_file)
# Out:
# Updating: January 2015 GRIT
# Updating: February 2015 GRIT
# Updating: March 2015 GRIT
# Updating: April 2015 GRIT
# Updating: May 2015 GRIT
# Updating: June 2015 GRIT
# Updating: July 2015 GRIT
# Updating: August 2015 GRIT
# Updating: September 2015 GRIT
# Updating: October 2015 GRIT
# Updating: November 2015 GRIT
# Updating: December 2015 GRIT
# Updating: January 2016 GRIT
# Updating: February 2016 GRIT
# Updating: March 2016 GRIT
# Updating: April 2016 GRIT
# Updating: May 2016 GRIT
# Updating: June 2016 GRIT
# Updating: July 2016 GRIT
# Updating: August 2016 GRIT
# Updating: September 2016 GRIT
# Updating: October 2016 GRIT
# Updating: November 2016 GRIT
# Updating: December 2016 GRIT

# %%
issues_to_update
# Out:
# [{'id': 118,
#   'slug': 'january-2015-grit',
#   'articles': [{'title': 'SHHAAnnual Meeting announcements',
#     'author': 'SHHA',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['3']},
#    {'title': 'Covenant Violation',
#     'author': 'Dick Wavrik',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['10']},
#    {'title': 'Bernalillo County Ordinance Regarding Animals',
#     'author': 'E&S',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['11']},
#    {'title': 'Light Pollution',
#     'author': 'Dick Wavrik',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['24']},
#    {'title': 'SHHAHOA Complaince',
#     'author': 'SHHA',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['31']},
#    {'title': 'Trash and Recycle Bins',
#     'author': 'Dick Wavrik',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['33']}]},
#  {'id': 117,
#   'slug': 'february-2015-grit',
#   'articles': [{'title': 'SHHAAnnual Meeting announcements',
#     'author': 'SHHA',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['3']},
#    {'title': 'Snow Removal',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['8']},
#    {'title': 'PNM Wants 12% Rate Hike',
#     'author': 'Bob Bower',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['9']},
#    {'title': 'Weed and Fire Season is Approaching!',
#     'author': 'Emily Rudin',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['23']},
#    {'title': 'Septic Tank Quick Tips',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['25']},
#    {'title': 'Empty Nest - Rooms for Rent',
#     'author': 'Dick Wavrik',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['27']},
#    {'title': 'Trash and Recycle Bins',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['33']}]},
#  {'id': 116,
#   'slug': 'march-2015-grit',
#   'articles': [{'title': 'Annual Reports from SHHACommittees',
#     'author': 'SHHA',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['3']},
#    {'title': 'How to Make Love to a Cholla Cactus',
#     'author': 'Letter to the Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']}]},
#  {'id': 115,
#   'slug': 'april-2015-grit',
#   'articles': [{'title': 'Know How Your Architectural Control Committee (CSC) Works',
#     'author': 'Bob Bower',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['2']},
#    {'title': 'The GRIT',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['19']},
#    {'title': 'Covenant Support Committee',
#     'author': 'Dick Wavrik',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['28']},
#    {'title': 'Finance Committee',
#     'author': 'Woody Farber',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['31']},
#    {'title': 'NM HOA Act & SHHAService Feedback',
#     'author': 'George Connor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['31']},
#    {'title': 'Birds of Special Interest and Concern are Found in Sandia Heights',
#     'author': 'Judy Liddell',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['37']}]},
#  {'id': 114,
#   'slug': 'may-2015-grit',
#   'articles': [{'title': 'Construction Courtesy & Safety in Sandia Heights',
#     'author': 'Bob Bower',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['2']},
#    {'title': 'The GRIT',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['19']},
#    {'title': 'Landscaping and Home Maintenance',
#     'author': 'Dick Wavrik',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['23']},
#    {'title': 'House Trailers, Trailers, and Recreational Vehicles',
#     'author': 'Dick Wavrik',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['28']},
#    {'title': 'Parks and Safety  ',
#     'author': 'George Connor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']},
#    {'title': 'Bear Season is Here',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['36']}]},
#  {'id': 113,
#   'slug': 'june-2015-grit',
#   'articles': [{'title': 'Bernalillo County Ordinance Regarding Animals',
#     'author': 'E&S',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['11']},
#    {'title': 'Parks and Safety Committee',
#     'author': 'George Connor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']},
#    {'title': 'Trash and Recycle Bins',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['33']},
#    {'title': 'Bobcats',
#     'author': 'Kate Fry',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['44']}]},
#  {'id': 112,
#   'slug': 'july-2015-grit',
#   'articles': [{'title': 'Street Right of Way Maintenance',
#     'author': 'George Connor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['8']},
#    {'title': "Zoning Variance Request made for a Domino's restaurant",
#     'author': 'George Connor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['14']},
#    {'title': 'On-line GRIT Newsletter',
#     'author': 'George Connor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['19']},
#    {'title': 'Parks & Safety Committee',
#     'author': 'George Connor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']},
#    {'title': "What, You Don't Yet Have Solar Panels?",
#     'author': 'Letter to the Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['32']},
#    {'title': 'Trash and Recycle Bins',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['33']},
#    {'title': 'Gnats Bugging You?',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['41']}]},
#  {'id': 111,
#   'slug': 'august-2015-grit',
#   'articles': [{'title': 'Surveys and Building Permints - a Refresher',
#     'author': 'Bob Bower',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['2']},
#    {'title': 'Proposed Art Work at W.L. Jackson Park',
#     'author': 'George Connor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['5']},
#    {'title': 'Property Owner Responsibilities in Bernalillo County Rights of Way Corner Properties',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['8']},
#    {'title': 'Covenant Support Committee',
#     'author': 'Josephine Porter',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['10']},
#    {'title': 'Bernalillo County Ordinance Regarding Animals',
#     'author': 'E&S',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['11']},
#    {'title': 'Albuquerque Police Department Crime Prevention Unit',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']},
#    {'title': 'Parks & Safety Committee',
#     'author': 'George Connor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']}]},
#  {'id': 110,
#   'slug': 'september-2015-grit',
#   'articles': [{'title': 'Dead Tree Cutting and Removal',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['15']},
#    {'title': 'Weeds and Landscaping',
#     'author': 'Josephine Porter',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['23']},
#    {'title': 'Responding to Emergency Situations',
#     'author': 'Bob Bower',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['25']},
#    {'title': 'Development News in Sandia Heights',
#     'author': 'George Connor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['31']},
#    {'title': 'Don’t Feed The Bears',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['36']}]},
#  {'id': 109,
#   'slug': 'october-2015-grit',
#   'articles': [{'title': 'Architectural Control Committee',
#     'author': 'Bob Bower',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['2']},
#    {'title': "Update on PNM's Rate Hike Request",
#     'author': 'Bob Bower',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['2']},
#    {'title': 'Covenant Support Committee',
#     'author': 'Josephine Porter',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['10']},
#    {'title': 'Contractor Evaluations',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['25']},
#    {'title': 'Drag Racing a Safety Concern for Sandia Heights',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']},
#    {'title': 'Pedestrian Safety Reminders',
#     'author': 'E&S',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']}]},
#  {'id': 108,
#   'slug': 'november-2015-grit',
#   'articles': [{'title': 'Covenant Support Committee',
#     'author': 'Josephine Porter',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['10']},
#    {'title': 'Renters and Membership Benefits',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['9']},
#    {'title': "SHHA's Recent 3-Month Tree Removal Program a Success",
#     'author': 'E&S',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['14']},
#    {'title': "Don't Let Your Water Pipes Freeze!",
#     'author': 'Bob Bower',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['25']},
#    {'title': 'Pedestrian Safety Reminders',
#     'author': 'E&S',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']},
#    {'title': 'Trash and Recycle Bins',
#     'author': 'CSC',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['33']}]},
#  {'id': 107,
#   'slug': 'december-2015-grit',
#   'articles': [{'title': 'Preliminary and Final Design and Construction Plans',
#     'author': 'Bob Bower',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['2']},
#    {'title': 'Snow Removal',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['8']},
#    {'title': 'Mhoon Property R-2 Zone Change Filed',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['9']},
#    {'title': 'Bernalillo County Ordinance Regarding Animals',
#     'author': 'E&S',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['11']},
#    {'title': 'Parks & Safety Committee',
#     'author': 'George Connor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['14']},
#    {'title': 'Holiday Security Tips',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']}]},
#  {'id': 106,
#   'slug': 'january-2016-grit',
#   'articles': [{'title': 'Snow Removal',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['8']},
#    {'title': 'SHHAHomeowner Members can Log onto the SHHAWebsite',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['9']},
#    {'title': 'Covenant Violation',
#     'author': 'CSC',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['10']},
#    {'title': 'Sandia Heights Recyling Update',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['14']},
#    {'title': 'What to do with that Christmas tree?',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['14']},
#    {'title': 'SHHAwants your thoughts on GRIT publication schudule!',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['19']},
#    {'title': 'Mail Theft',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']},
#    {'title': 'New Board Candidates Biographies',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['31']},
#    {'title': 'SHHAAnnual Meeting',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['31']},
#    {'title': 'Trash and Recycle Bins',
#     'author': 'CSC',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['33']}]},
#  {'id': 105,
#   'slug': 'february-2016-grit',
#   'articles': [{'title': 'To Plow or Not to Plow? Tramway and Snow/Ice',
#     'author': 'Cindy Mottle',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['8']},
#    {'title': 'Communications and Publications - What does it do?',
#     'author': 'Cindy Mottle',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['9']},
#    {'title': 'Covenant Violation',
#     'author': 'CSC',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['10']},
#    {'title': 'Responding to Emergency Situations',
#     'author': 'Bob Bower',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['25']},
#    {'title': 'Mail Theft',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']},
#    {'title': "Update on the County's Drag Racing Issue",
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']},
#    {'title': 'SHHAAnnual Meeting',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['31']},
#    {'title': 'Trash and Recycle Bins',
#     'author': 'CSC',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['33']}]},
#  {'id': 104,
#   'slug': 'march-2016-grit',
#   'articles': [{'title': 'SHHA2016 Annual Meeting Officer and Committee Reports',
#     'author': 'SHHA',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['3']},
#    {'title': 'Sandia Homeowners Backyard Ski Area',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['9']},
#    {'title': 'BernCo and SHS Report Increase in Mail Theft',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']},
#    {'title': 'Bow Hunting in Cibola',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']}]},
#  {'id': 103,
#   'slug': 'april-2016-grit',
#   'articles': [{'title': "A Refresher on the Architectural Control Committee's Neighborhood Review Process",
#     'author': 'Bob Bower',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['2']},
#    {'title': 'Kudos to John Betak',
#     'author': 'Joe Pappe',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['8']},
#    {'title': 'Communiations & Publication Committee',
#     'author': 'C&P',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['9']},
#    {'title': 'Travel Trends for 2016',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['9']},
#    {'title': 'Construciton Started to Provide Quicker Architectural Control Committeeess to Paseo for Fire Station #35',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['15']},
#    {'title': 'Landscaping and Home Maintenance from the CSC',
#     'author': 'Josephine Porter',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['23']},
#    {'title': 'ABQ Film Shows Dangers of Local Cycling',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']},
#    {'title': 'SHHASecretary Report',
#     'author': 'George Connor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['31']}]},
#  {'id': 102,
#   'slug': 'may-2016-grit',
#   'articles': [{'title': 'Hawks Landing Development Update',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['9']},
#    {'title': 'Volunteers Needed!',
#     'author': 'C&P',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['9']},
#    {'title': 'CSC Needs Volunteers',
#     'author': 'CSC',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['10']},
#    {'title': 'Fire Weather Warning',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['15']},
#    {'title': 'Choosing Your Contractor',
#     'author': 'Bob Bower',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['25']},
#    {'title': 'Covenant Support Committee',
#     'author': 'CSC',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['28']},
#    {'title': 'How to Stop the Door-to-Door Sales People',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']},
#    {'title': 'Pedestrian Safety Reminders',
#     'author': 'E&S',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']},
#    {'title': 'SHHASecretary Report',
#     'author': 'George Connor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['31']},
#    {'title': 'Keep Bears Wild',
#     'author': 'Dave Mottle',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['36']}]},
#  {'id': 101,
#   'slug': 'june-2016-grit',
#   'articles': [{'title': 'Mhoon/Hawks Landing Update',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['9']},
#    {'title': 'Volunteers Needed!',
#     'author': 'C&P',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['9']},
#    {'title': 'You, the SHHA, Covenant Enforcement, and Anonymous Complaints',
#     'author': 'CSC',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['10']},
#    {'title': 'Barking Dogs - CSC or BernCo?',
#     'author': 'CSC',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['11']},
#    {'title': 'SHHAwants your thoughts on GRIT Online vs. Printed',
#     'author': 'Cindy Mottle',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['19']},
#    {'title': 'Sandia Heights Services Water Conservation Tips',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['25']},
#    {'title': 'Tips for your Home Remodeling Projects',
#     'author': 'Bob Bower',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['25']},
#    {'title': 'Don’t Squash this Bug!',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['41']}]},
#  {'id': 100,
#   'slug': 'july-2016-grit',
#   'articles': [{'title': 'Bernalillo Road Maintenance Services',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['8']},
#    {'title': 'Storm Drains on County Easements and Streets',
#     'author': 'Dave Mottle',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['8']},
#    {'title': 'BERNCO Commission Adopts Peak Dining and Sandia Peak Ski…',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['31']},
#    {'title': 'Meet and Greet with BERNCO Sherrif Dunlap a Success',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['31']},
#    {'title': "What's Cool in July",
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['9']},
#    {'title': 'Walking and Cycling on the Tramway Blvd. Bike Path',
#     'author': 'Anne Manning',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']},
#    {'title': 'Good News about Solar Panels',
#     'author': 'Odile de la Beaujardiere',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['32']},
#    {'title': 'Be Bear Aware',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['36']}]},
#  {'id': 99,
#   'slug': 'august-2016-grit',
#   'articles': [{'title': 'Parks and Safety Committee',
#     'author': 'George Connor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['9']},
#    {'title': 'Light Pollution',
#     'author': 'CSC',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['24']},
#    {'title': 'Emergency and Non-Emergency Upgrades to your Residence',
#     'author': 'Bob Bower',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['25']},
#    {'title': 'Home Security When Traveling',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']},
#    {'title': 'Snakes and You',
#     'author': 'Dave Mottle',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['43']}]},
#  {'id': 98,
#   'slug': 'september-2016-grit',
#   'articles': [{'title': "Update on PNM's Rate Hike Request",
#     'author': 'Bob Bower',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['2']},
#    {'title': "Why doesn't the CSC do anything with my complaint?",
#     'author': 'Dick Wavrik',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['10']},
#    {'title': 'Walking Dogs along the Domingo Baca Arroyo',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['11']},
#    {'title': 'SHHASewers - 4 Things Not to Put Down the Drain',
#     'author': 'Architectural Control Committee',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['14']},
#    {'title': 'Dead Trees - Parks & Safety Committee',
#     'author': 'E&S',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['15']},
#    {'title': 'Day Tour - Tijeras Pueblo and Tourquoise Trail',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['20']},
#    {'title': 'A Little Goes a Long Way',
#     'author': 'CSC',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['24']},
#    {'title': 'The Empty Nest - Rooms for Rent',
#     'author': 'CSC',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['27']},
#    {'title': 'Back to School Safety Checklist',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']}]},
#  {'id': 97,
#   'slug': 'october-2016-grit',
#   'articles': [{'title': 'Street Right of Way Maintenance',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['8']},
#    {'title': 'Fourth of july Canyon Visit',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['9']},
#    {'title': 'Volunteers Needed!',
#     'author': 'C&P',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['9']},
#    {'title': 'Covenant Support Committee (CSC)',
#     'author': 'Dick Wavrick',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['10']},
#    {'title': 'Contractor Evaluations',
#     'author': 'SHHA',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['25']},
#    {'title': "Don't Let Your Water Pipes Freeze!",
#     'author': 'Bob Bower',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['25']},
#    {'title': 'Halloween Trick or Treat Reminder',
#     'author': 'E&S',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']},
#    {'title': 'SHHASecurity Alert',
#     'author': 'SHHA',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']},
#    {'title': "Second Meet and Greet with Benalillo County Sheriff's…",
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['31']},
#    {'title': 'Trash and Recycle Bins',
#     'author': 'CSC',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['33']},
#    {'title': 'Fall Bear Alert',
#     'author': 'E&S',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['36']}]},
#  {'id': 96,
#   'slug': 'november-2016-grit',
#   'articles': [{'title': 'Special Use Permits and the Architectural Control Committee',
#     'author': 'Bob Bower',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['2']},
#    {'title': 'Volunteers Needed!',
#     'author': 'C&P',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['9']},
#    {'title': 'A Tale of Two Covenants',
#     'author': 'Dick Wavrik',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['10']},
#    {'title': 'Covenant Support Committee (CSC) Needs Volunteers',
#     'author': 'CSC',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['10']},
#    {'title': 'If You are a Responsible Home Owner Do Not Read',
#     'author': 'Dick Wavrik',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['10']},
#    {'title': 'Bernalillo County Ordinance Regarding Animals',
#     'author': 'E&S',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['11']},
#    {'title': 'Roadside Mowing - Before Winter',
#     'author': 'E&S',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['14']},
#    {'title': 'Heat Pump Tips',
#     'author': 'Architectural Control Committee',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['25']},
#    {'title': 'Rental Property',
#     'author': 'CSC',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['27']},
#    {'title': "Balloon Fiesta is Gone…and the RV's Should be Gone",
#     'author': 'CSC',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['28']},
#    {'title': 'Welcome New Board Members',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['31']}]},
#  {'id': 95,
#   'slug': 'december-2016-grit',
#   'articles': [{'title': 'Sandia Homeowners Backyard Ski Area',
#     'author': "Burt O'Neil",
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['9']},
#    {'title': 'Coventan Support Committee (CSC) Needs Volunteers',
#     'author': 'CSC',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['10']},
#    {'title': 'Meet and Greet Success Continues with Captain Kingsbury',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['9']},
#    {'title': 'Fall Green Waste Collection',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['14']},
#    {'title': 'Holiday Lighting and Parking',
#     'author': 'Dick Wavrick',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']},
#    {'title': 'Mail Theft',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']},
#    {'title': 'Security Reminder',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']},
#    {'title': 'Snow Removal',
#     'author': 'Editor',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['29']},
#    {'title': 'A Letter Form Your Vice President - Bob Bower',
#     'author': 'Bob Bower',
#     'created_at': '2024-10-12 08:51:06',
#     'category': ['31']}]}]

# %%
issues_to_update = []

for issue in all_issues:
    print(issue['slug'])

#issue['articles'] = slug_articles_dict
# Out:
# october-2024-grit
# september-2024-grit
# august-2024-grit
# july-2024-grit
# june-2024-grit
# may-2024-grit
# april-2024-grit
# march-2024-grit
# february-2024-grit
# january-2024-grit
# december-2023-grit
# november-2023-grit
# 2023-october-grit
# september-2023-grit
# august-2023-grit-revised
# august-2023-july-grit
# july-2023-grit
# june-2023-grit
# may-2023-grit
# april-2023-grit
Users/heidi/Documents/SHHA/GRIT/GRIT_archive_AI_summaries/'

updated_data = []
for item in current_data:
    pdf = item['file']
    year = item['file'].split('-')[-1].split('_')[0] 
    month = item['file'].split('-')[-1].split('_')[1][0:2]
    
    # create new item with minimum info
    new_item = {}
    new_item['id'] = item['id']
    
    # Edit image path
    new_item['image'] = pdf[:-4] + '.png'

    # Edit text path
    '''
    text_file = os.path.basename(item['file'])[:-4]+'_summary.txt'  
    text_file_path = os.path.join(text_folder,year,text_file)
    if os.path.exists(text_file_path):
        text = open(text_file_path).read()
        item['content'] = text
    '''
    updated_data.append(new_item)

# %%
filename = f"content_grit_{datetime.now().strftime('%y%m%d%H%M')}.json"
with open(filename, 'w') as f:
    json.dump(updated_data, f)

# %%
month

# %%
text_file

# %%
text

# %% [markdown]
# ## parse each entry and create an updated json

# %%
# update the existing entries
updated_data = []
existing_YM_entries = []
for item in current_data:
    year,month = extract_year_month(item['slug'])
    item['file'] = '/grit/'+year+'/SHHA-GRIT-'+year+'_'+month+'.pdf'
    updated_data.append(item)
    existing_YM_entries.append(year+month)

# %%
#with open('updated_data.json', 'w') as json_file:
#    json.dump(updated_data, json_file)

# %%
df = pd.DataFrame(updated_data)

df['Title'] = df['title']
df['Slug'] = df['slug']
df['Enabled Date'] = df['grit_date']
df['File'] = df['file'] 
df['ID'] = df['id']
df = df[['ID','Title','Slug','Enabled Date','File']]

#df.to_csv('updated_data.csv')

# %%
df.to_csv('updated_data.csv')

# %% [markdown]
# ## Add in new data

# %%
# Now, add data that doesn't yet exist

# Find the entries that are in PDF but not in JSON
new_YM_entries = []
for root, dirs, files in os.walk('./GRIT_archive'):
    for f in files:
        if f.endswith('pdf'):
            f = f.split('-')[-1].split('.')[0]
            year,month = f.split('_')
            if year+month not in existing_YM_entries:
                new_YM_entries.append((year,month))
new_YM_entries = sorted(new_YM_entries, key=lambda x: (x[0], x[1]), reverse=True)
new_YM_entries = [(int(y),int(m)) for y,m in new_YM_entries]

starting_id = max([int(item['id']) for item in current_data])
data_new = []    
for i, (year, month) in enumerate(new_YM_entries):
    month_name_str = month_name[month]
    grit_date = f"{year}-{month:02d}-01 00:00:00"
    file_path = f"/grit/{year}/SHHA-GRIT-{year}_{month:02d}.pdf"

    entry = {
        'id': starting_id + i,
        'title': f"{month_name_str} {year} GRIT",
        'slug': f"{month_name_str.lower()}-{year}-grit",
        'is_enabled': 1,
        'published_at': datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
        'expired_at': None,
        'content_group': None,
        'grit_date': grit_date,
        'file': file_path
    }

    data_new.append(entry)

# %%
df = pd.DataFrame(data_new)

df['Title'] = df['title']
df['Slug'] = df['slug']
df['Enabled Date'] = df['grit_date']
df['File'] = df['file'] 
df['ID'] = df['id']
df = df[['ID','Title','Slug','Enabled Date','File']]

df.to_csv('data_new.csv')

# %% [markdown]
# # Finally, fix the URL issue

# %%
df = pd.read_csv('content_grit_combined_badURL.csv')

# %%
df['File'] = df['File'].apply(lambda x: x[1:] if isinstance(x, str) else x)
df

# %%
df.to_csv('content_fixed_filepaths.csv')
